# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
generator = pipeline('text-generation', model='EleutherAI/gpt-neo-125M')

# %%
prompt = 'Artificial intelligence is'
res = generator(prompt, max_length=1000, do_sample=True, temperature=0.9)

# %%
print(res[0]['generated_text'])
# Out:
# Artificial intelligence is being used widely to determine the actions of a large number of objects in nature, including the environment. Intelligent robots which can interact with humans on a remote level may help to make the world of space much more "smart."
#
# However, there are also some problems with artificial intelligence.
#
# Most intelligent robots rely on data from a limited number of sensors. When the sensors are too small, they may not have enough information to make a decision, especially when the user has large amounts of data. The problem becomes even more severe when the sensors are too large, such as when many objects may be on a floor. The data may be processed to determine objects which are not necessary. This information may help the robot to control the user, like controlling a camera.
#
# The technology described by the author is based on "the technology of real-world objects" as described by John Devereaux, “Real-world objects in the real world”. The real-world objects in the real world are artificial objects, which are not only intelligent but also physical.
#
# The technology describes a robot whose action is determined by the data that are collected by the sensors. The robot operates like a human, but the robot’s behavior is governed by data generated by the sensors. The robot is controlled by a computer which is computer-generated, and by a human which is computer-generated.
#
# The robot is not limited by its ability to control the user. It can help robots to determine the actions of objects in a wide range of settings, like where the user is standing, the time when the user is laying hands, etc.
#
# Even though the research is based on real-world objects, AI makes use of a limited number of sensors. Some objects such as objects on a ceiling stand are even more complex. The robot must be controlled by a human and the robot can only perform tasks if this human could move a position around the room at a time.
#
# While the human can move objects at large distances, the robot can easily follow that object by using other objects as an input. A robot which can move a position around a room at a time can use different kinds of inputs from the human.
#
# The robot uses machine learning techniques to learn the behavior of the robots, and it has to learn the data from the sensors, which is then analyzed to make a decision. This research has already led to a robot that has better intelligence than humans.
#
# The research of the authors is designed to help the scientists and the general public understand the research, as this research is not based on real-world objects. However it does show some basic concepts like how human and robot can work together to make the world of stars more similar to what they see.
#
# The technology is not based on humans. Instead the technology was based on "real-world objects" that "real people" would interact with on a remote level, or that other computer-generated "humans" would interact with. This technology will help the scientists, the general public and the robot to understand what is real and what is artificial.
#
# There are many people who will interact with a robot. One can choose or do this on another computer or a remote computer. There are many robot types that interact with humans. Some robots can be artificial. Some robots can be computer-generated. Some robots can be human. These computer-generated robots are in different stages of development.
#
# In a typical robot, a human can walk around the room. The robot can also do some data-and-feeds-to-the-human-which also makes the life of the robot easier. The robot can do these functions all at once.
#
# Some robots can be artificial if the robot does some data-and-feeds-to-the human. Some robot types have many tasks to do, like moving a chair. Some robots are much more complex. Some can also be AI-built and AI-built, but without human control because the robot’s behavior is artificial.
#
# Some robots can be AI-built and AI-built, but they are not in real-world environment. The robot has to learn.
#
# Some robots have to be AI-built as well at a remote level, and there must be a human on a remote level.
#
# In this research, the authors used "AI-building to make the world of life more like it is like it is", but there needs to be human control over the robot. In order to use this technology in the future, the research will need to be performed by "real people". This is not the science of the research.
#
# Answering the question: "How can we make the life of a robot"
#
# How is AI-built, and how can robot-engineers make the world of space more like it
